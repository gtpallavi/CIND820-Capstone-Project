# %%
#Import the dataset
import pandas as pd
import numpy as np
#df = pd.read_csv("C:/Users/balam/OneDrive/Documents/PallaviC820/Data/covid19_tweets.csv")
df = pd.read_csv("FullTweets.csv", encoding = "utf-8-sig", sep = ",")

# %%
#The shape of the dataset, number of rows and columns
print("There are {} rows and {} columns in the dataset.".format(df.shape[0],df.shape))
# Out:
# There are 105000 rows and (105000, 13) columns in the dataset.

# %%
#Preprocessing and data cleanup
df['is_retweet'] = df['is_retweet'].fillna(False)
#df.replace({'user_verified': {'TRUE': True, 'FALSE': False}})
#df['user_verified'] = df['user_verified'].astype('bool')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105000 entries, 0 to 104999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_name         105000 non-null  object
#  1   user_location     78321 non-null   object
#  2   user_description  96038 non-null   object
#  3   user_created      105000 non-null  object
#  4   user_followers    105000 non-null  int64
#  5   user_friends      105000 non-null  int64
#  6   user_favourites   105000 non-null  int64
#  7   user_verified     105000 non-null  bool
#  8   date              105000 non-null  object
#  9   text              105000 non-null  object
#  10  hashtags          39311 non-null   object
#  11  source            105000 non-null  object
#  12  is_retweet        105000 non-null  bool
# dtypes: bool(2), int64(3), object(8)
# memory usage: 9.0+ MB

# %%
df.head()
# Out:
#         user_name     user_location  \
# 0     needlenose5       Milford, CT
# 1    workonline44               NaN
# 2    Uab_BabaKofi     Virginia, USA
# 3  ActivistBowen2         Hong Kong
# 4      RAChampion  Sydney Australia
#
#                                     user_description  \
# 0  Husband, dad to kids. Pro Trump. GPU head, Sub...
# 1                                                NaN
# 2  Dad of two daughters, husband, Consulting IT S...
# 3  AMERICAN EXPAT in HONG KONG, person, blogger, ...
# 4  Digital Marketing, Brand Promotion & Social Me...
#
#                 user_created  user_followers  user_friends  user_favourites  \
# 0  2020-03-25 21:23:13+00:00              12            86             1089
# 1  2016-07-30 03:40:00+00:00           30136          1915               62
# 2  2016-03-05 21:10:37+00:00            9874         10842            41264
# 3  2011-06-08 20:17:01+00:00            4168          4997             5217
# ...

# %%
df.tail()
# Out:
#               user_name      user_location  \
# 104995        iTPcCares  New Delhi, India
# 104996       MarilsaAPC                NaN
# 104997  lotuseatersnews                NaN
# 104998      FrankieEAGB            Reality
# 104999         56sahara                NaN
#
#                                          user_description  \
# 104995  iTPcCares is enabling the digital world with i...
# 104996                                                NaN
# 104997                                                NaN
# 104998                                                NaN
# 104999               Direita \nConservador \nBolsonariano
#
#                      user_created  user_followers  user_friends  \
# 104995  2020-05-03 11:44:54+00:00              25           323
# 104996  2018-09-13 20:26:14+00:00            1404          5011
# 104997  2022-02-14 16:57:57+00:00            1148             9
# 104998  2021-09-28 18:45:52+00:00             257          1957
# ...

# %%
#Replace the NaNs
# df['user_location'] = df['user_location'].fillna("")
# df['user_description'] = df['user_description'].fillna("")
# df['hashtags'] = df['hashtags'].fillna("")
# df['user_friends'] = df['user_friends'].apply(int)
# df['user_followers'] = df['user_followers'].apply(int)
# df['user_favourites'] = df['user_favourites'].apply(int)
#df.info()

# %%
#!pip uninstall pandas-profiling
# !pip install pandas-profiling[notebook]

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df)
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-04-04 04:10:36.483210&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.head()

# %%
df.tail()

# %%
import seaborn as sns
import matplotlib
#matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
cm = sns.light_palette("green", as_cmap=True)
df.describe().style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_5cf30_row0_col0, #T_5cf30_row1_col0, #T_5cf30_row1_col1, #T_5cf30_row3_col0, #T_5cf30_row3_col1, #T_5cf30_row3_col2, #T_5cf30_row4_col0, #T_5cf30_row4_col1, #T_5cf30_row4_col2, #T_5cf30_row5_col0, #T_5cf30_row5_col1, #T_5cf30_row5_col2, #T_5cf30_row6_col0, #T_5cf30_row6_col1, #T_5cf30_row6_col2 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_5cf30_row0_col1 {
#   background-color: #c5e0c5;
#   color: #000000;
# }
# #T_5cf30_row0_col2 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_5cf30_row1_col2 {
#   background-color: #eaf2ea;
#   color: #000000;
# }
# #T_5cf30_row2_col0, #T_5cf30_row2_col1 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# #T_5cf30_row2_col2 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_5cf30_row7_col0, #T_5cf30_row7_col1, #T_5cf30_row7_col2 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5cf30">
#   <thead>
#     <tr>
# ...

# %%
#Heatmap of users with maximum number of followers
cm = sns.light_palette("green", as_cmap=True)
df.head(10).style.background_gradient(cmap=cm)

# %%
missing_values = pd.DataFrame()
missing_values['column'] = df.columns

missing_values['percent'] = [round(100* df[col].isnull().sum() / len(df), 2) for col in df.columns]
missing_values = missing_values.sort_values('percent')
missing_values = missing_values[missing_values['percent']>0]
plt.figure(figsize=(15, 5))
sns.set(style='whitegrid', color_codes=True)
splot=sns.barplot(x='column', y='percent', data=missing_values)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.2f'), (p.get_x() + p.get_width() / 2., p.get_height()), ha = 'center',
                   va = 'center', xytext = (0, 9), textcoords = 'offset points')
plt.xlabel("Column_Name", size=14, weight="bold")
plt.ylabel("Percentage", size=14, weight="bold")
plt.title("Percentage of missing values in column",fontweight="bold",size=17)
plt.show()

# %%
# !pip install millify
# !pip install plotly
from millify  import millify
import plotly.graph_objs as go
import plotly.express    as px
matplotlib.rcParams['font.sans-serif'] = ['Source Han Sans TW', 'sans-serif']

# %%
#Plot the users with maximum number of followers
# %matplotlib inline
data = df.sort_values('user_followers',ascending=False).drop_duplicates(subset='user_name', keep="first")
data = data[['user_name', 'user_followers']]

data1 = data.head(50).reset_index().copy()
for i in range(50):
    data1['user_followers'][i] = millify(data1['user_followers'][i],precision=2)
data1['user_followers'] = data1['user_followers'].str[:-1].astype(float) 

plt.figure(figsize=(15, 17))

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

sns.barplot(y='user_name',x='user_followers',data=data1.head(50))
y=data1['user_followers'].head(50)
for index, value in enumerate(y):
    plt.text(value, index, str(value),fontsize=12)
plt.title('Top50 users by number of followers',weight='bold', size=15)
plt.ylabel('User_name', size=12, weight='bold')
plt.xlabel('Followers_count( in Millions )', size=12, weight='bold')
plt.show()
# Out:
# <ipython-input-15-34941efcdd54>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['user_followers'][i] = millify(data1['user_followers'][i],precision=2)

# %%
plt.figure(figsize=(10,12))

plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

sns.barplot(x = df["user_location"].value_counts().values[0:10],
            y = df["user_location"].value_counts().index[0:10]);
plt.title("Top 10 Countries with maximum tweets",fontsize=14)
plt.xlabel("Number of tweets",fontsize=14)
plt.ylabel("Country",fontsize=14)
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x ="user_verified",data=df, palette="Set2")
plt.title("Verified user accounts or not ?")
plt.xticks([False,True],['Unverified','Verified'])
plt.show()

# %%
plt.figure(figsize=(15,5))
src = df['source'].value_counts().sort_values(ascending=False)
source = src.head(10)
source.plot.bar(color=['red', 'green', 'blue', 'black','cyan','pink','purple','violet','yellow','orange'])
plt.title('Platform with maximum number of tweets',size=13)
plt.xlabel('User Platform',size=13)
plt.ylabel('Tweet Count',size=13)
plt.show()

# %%
top_tags=df['hashtags'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(8,8))
explode = (0, 0.1, 0, 0,0.005) 

top_tags[0:10].plot(kind = 'pie',title = 'Top 10 hashtags',autopct='%1.1f%%',shadow=False,explode = None)
# Out:
# <AxesSubplot:title={'center':'Top 10 hashtags'}, ylabel='hashtags'>

# %%
def plot_frequency_charts(df, feature, title, pallete):
    freq_df = pd.DataFrame()
    freq_df[feature] = df[feature]
    
    f, ax = plt.subplots(1,1, figsize=(16,4))
    total = float(len(df))
    g = sns.countplot(df[feature], order = df[feature].value_counts().index[:20], palette=pallete)
    g.set_title("Number and percentage of {}".format(title))

    for p in ax.patches:
        height = p.get_height()
        ax.text(p.get_x()+p.get_width()/2.,
                height + 3,
                '{:1.2f}%'.format(100*height/total),
                ha="center") 

    plt.title('Frequency of {} tweeting about Corona'.format(feature),weight='bold', size=15)
    plt.ylabel('Frequency', size=12, weight='bold')
    plt.xlabel(title, size=12, weight='bold')
    plt.xticks(rotation=90)
    plt.show()
